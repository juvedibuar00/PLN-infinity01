# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
url = pd.read_csv("https://raw.githubusercontent.com/natorjunior/debates-ideologicos/main/dataset.csv")

# %%
url
# Out:
#                                                    Text  Label
# 0     diego freitas e a jovem pobre q mora no morro ...      1
# 1     moral e algo pessoal não tente enfiar seus val...      1
# 2     eu acho engraçado que se posicionar sobre o út...      1
# 3     adriano barboza da mesma forma como vc demonst...      1
# 4     a vida termina qnd acaba atividade cerebral en...      1
# ...                                                 ...    ...
# 1765  e assustador ver pessoas defendendo a eugenia ...      0
# 1766  no dia em que a medicina conseguir descobrir q...      0
# 1767  tenho minhas ideias sobre o aborto não sou rel...      0
# 1768  melhor comentario leia e difícil entender a ta...      0
# 1769  aborto mesmo tirando o lado religioso e uma qu...      0
#
# [1770 rows x 2 columns]

# %%
url.describe()
# Out:
#              Label
# count  1770.000000
# mean      0.438983
# std       0.496403
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Label'].plot(kind='hist', bins=20, title='Label')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Label'].plot(kind='line', figsize=(8, 4), title='Label')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
url.Label.value_counts().plot.pie()
# Out:
# <Axes: ylabel='Label'>

# %%
url.Label.value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# NUVEM DE PALAVRAS

# %%
# Gerando a nuvem de palavras

# %%
url
txt = ' '.join(url['Text'].values)
txt = ' '.join(url['Text'].values)
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(txt)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
txt
# Out:
# 'diego freitas e a jovem pobre q mora no morro sem instrução e a criança q vai nascer e viver em pessimas condições e cair na criminalidade e facil falar sobre proibição do aborto qundo se e homem de classe media moral e algo pessoal não tente enfiar seus valores morais em outra pessoa isso não existe sou a favor da legalização do aborto não sou a favor do aborto isso e uma escolha da mulher afinal quem paga o pato depois somos nós mesmas não e quem quer abortar vai abortar sendo legal ou não e quem não quer abortar não vai fazer sendo legal ou não ou vocêa acham que com a legalização do aborto vão ter comerciais na tv falando e aí ta sem nada pra fazer vamos fazer um abortinho eu acho engraçado que se posicionar sobre o útero alheio e mto facil se homem engravidasse aborto ja era legalizado falar que e feio crime e bla bla bla e facil pílula do dia seguinte falha camisinha estoura diu sai do lugar e um monte de outras coisas acontecem são adversidades enfiar criança no orfanato tmbm
# ...

# %%
label1 = url.query("Label == 1")

# %%
label1
# Out:
#                                                   Text  Label
# 0    diego freitas e a jovem pobre q mora no morro ...      1
# 1    moral e algo pessoal não tente enfiar seus val...      1
# 2    eu acho engraçado que se posicionar sobre o út...      1
# 3    adriano barboza da mesma forma como vc demonst...      1
# 4    a vida termina qnd acaba atividade cerebral en...      1
# ..                                                 ...    ...
# 772  jose sergio carvalho seu último paragrafo tamb...      1
# 773  poxa hitler nunca foi tão contemporâneo e viva...      1
# 774  de quem o direito de decidir a não ser o da pe...      1
# 775  vivemos em um país atrasado com muito dos polí...      1
# 776  eu penso que esse direito deve ser dado a mulh...      1
#
# [777 rows x 2 columns]

# %%
label0 = url.query("Label == 0")

# %%
label0
# Out:
#                                                    Text  Label
# 777   quando não se deseja gravidez usa se preservat...      0
# 778   mas como funcionara isso na pratica num país o...      0
# 779   o aborto causa mais traumas físicos e sequelas...      0
# 780   eu sou ateia e não acho que seja questão relig...      0
# 781   e meu caro henrique alvarez e a triste desuman...      0
# ...                                                 ...    ...
# 1765  e assustador ver pessoas defendendo a eugenia ...      0
# 1766  no dia em que a medicina conseguir descobrir q...      0
# 1767  tenho minhas ideias sobre o aborto não sou rel...      0
# 1768  melhor comentario leia e difícil entender a ta...      0
# 1769  aborto mesmo tirando o lado religioso e uma qu...      0
#
# [993 rows x 2 columns]

# %%
url
txt = ' '.join(label1['Text'].values)
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(txt)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
url
txt = ' '.join(label0['Text'].values)
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', min_font_size = 10).generate(txt)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# nltk = biblioteca que retira palavras do texto

# %%
# Baixar as stop words
nltk.download('stopwords')
# Lista de palavras (exemplo)
words = ["exemplo", "uma", "nuvem", "de", "palavras", "com", "e", "sem", "stop", "words"]
# Carregar as stop words em português
stop_words = set(stopwords.words('portuguese'))
# Filtrar as palavras, removendo as stop words
filtered_words = [word for word in words if word not in stop_words]

print(filtered_words)
# Out:
# ['exemplo', 'nuvem', 'palavras', 'stop', 'words']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download("stopwords")
stop_words = set(stopwords.words('portuguese'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
